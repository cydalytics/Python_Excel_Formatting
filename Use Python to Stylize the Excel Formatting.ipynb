# %% [markdown]
# # <center><font color='#333333'>Use Python to Stylize the Excel Formatting</font></center>
# ### <center><font color='#3b5998'>Created by cyda - Yeung Wong & Carrie Lo</font></center>

# %% [markdown]
# --------------------------------------------------------------------------------------
# ![logo](https://4.bp.blogspot.com/-LAXjdvVCYCU/WxeQFKQ-1wI/AAAAAAAAACs/o8IJ1eLLAEwQYv2Az7EqQi9jODTqRx7wACK4BGAYYCw/s1000/tight%2Bbanner_with_description.png)

# %% [markdown]
# --------------------------------------------------------------------------------------
# Please acknowledge <b>team cyda - Yeung Wong & Carrie Lo</b> when using the code
#
# <b><font color='#3b5998'>If you find this script is helpful, please feel free to endorse us through Linkedin!</font></b>
#
# <b>Linkedin:</b>
#
# Yeung Wong - https://www.linkedin.com/in/yeungwong/
#
# Carrie Lo - https://www.linkedin.com/in/carrielsc/
#
# --------------------------------------------------------------------------------------

# %% [markdown]
# # Step 1 - Data Scraping

# %%
import json
from urllib import request
url = "https://production.api.coindesk.com/v2/tb/price/ticker?assets=all"
response = request.urlopen(url)
data = json.loads(response.read().decode())
data
# Out:
# {'statusCode': 200,
#  'message': 'OK',
#  'data': {'BTC': {'iso': 'BTC',
#    'name': 'Bitcoin',
#    'slug': 'bitcoin',
#    'change': {'percent': 2.713846028057471, 'value': 1207.072774},
#    'ohlc': {'o': 44478.307226,
#     'h': 46843.67,
#     'l': 43480.540171,
#     'c': 45685.38},
#    'circulatingSupply': 18814943.79249204,
#    'marketCap': 859567856838.6399,
#    'ts': 1631606099000,
#    'src': 'tb'},
#   'ETH': {'iso': 'ETH',
#    'name': 'Ethereum',
#    'slug': 'ethereum',
#    'change': {'percent': 2.996461607015777, 'value': 96.209888},
#    'ohlc': {'o': 3210.783271, 'h': 3385, 'l': 3116.81, 'c': 3306.993159},
#    'circulatingSupply': 117224668.1714915,
#    'marketCap': 387661175709.1675,
#    'ts': 1631606099000,
#    'src': 'tb'},
#   'XRP': {'iso': 'XRP',
#    'name': 'XRP',
#    'slug': 'xrp',
#    'change': {'percent': 2.7825691560965105, 'value': 0.0291316994},
#    'ohlc': {'o': 1.0469353229,
#     'h': 1.0996056267,
#     'l': 1.0266491573,
#     'c': 1.0762684335},
#    'circulatingSupply': 99990179359.64815,
#    'marketCap': 107616273700.87338,
#    'ts': 1631606105000,
#    'src': 'cd'},
#   'BCH': {'iso': 'BCH',
#    'name': 'Bitcoin Cash',
#    'slug': 'bitcoin-cash',
#    'change': {'percent': 0.8628816256805922, 'value': 5.2710230449},
#    'ohlc': {'o': 610.8628215099,
#     'h': 659.9715062615,
#     'l': 592.5366042449,
#     'c': 616.2612458214},
#    'circulatingSupply': 18844941.88586577,
#    'marketCap': 11613407364.014797,
#    'ts': 1631606105000,
#    'src': 'cd'},
#   'ADA': {'iso': 'ADA',
#    'name': 'Cardano',
#    'slug': 'cardano',
#    'change': {'percent': 1.9163198708022753, 'value': 0.0451022472},
#    'ohlc': {'o': 2.3535865735,
#     'h': 2.5122783818,
#     'l': 2.3118219021,
#     'c': 2.3996382048},
#    'circulatingSupply': 32357324036.78788,
#    'marketCap': 77645870963.85843,
#    'ts': 1631606105000,
#    'src': 'cd'},
#   'XLM': {'iso': 'XLM',
#    'name': 'Stellar',
#    'slug': 'stellar',
#    'change': {'percent': 1.4469455142270713, 'value': 0.0045659132},
#    'ohlc': {'o': 0.3155552969,
#     'h': 0.3304328472,
#     'l': 0.3101153347,
#     'c': 0.3200973981},
#    'circulatingSupply': 105442002702.08649,
#    'marketCap': 33751710716.48895,
#    'ts': 1631606105000,
#    'src': 'cd'},
#   'NEO': {'iso': 'NEO',
#    'name': 'NEO',
#    'slug': 'neo',
#    'change': {'percent': 4.047721894975872, 'value': 1.9314492058},
#    'ohlc': {'o': 47.716944394,
#     'h': 50.9759184489,
#     'l': 45.8048167346,
#     'c': 49.6321245095},
#    'circulatingSupply': 100000000,
#    'marketCap': 4963212450.949891,
#    'ts': 1631606105000,
#    'src': 'cd'},
#   'LTC': {'iso': 'LTC',
#    'name': 'Litecoin',
#    'slug': 'litecoin',
#    'change': {'percent': 3.472150493673105, 'value': 6.0012919443},
#    'ohlc': {'o': 172.8407785087,
#     'h': 236.2595437897,
#     'l': 170.93903405,
#     'c': 178.88651502},
#    'circulatingSupply': 68528527.66738841,
#    'marketCap': 12258829493.868359,
#    'ts': 1631606105000,
#    'src': 'cd'},
#   'EOS': {'iso': 'EOS',
#    'name': 'EOS',
#    'slug': 'eos',
#    'change': {'percent': 4.718292126025149, 'value': 0.2165180994},
#    'ohlc': {'o': 4.5889083087,
#     'h': 4.9451184163,
#     'l': 4.4921615326,
#     'c': 4.8065851484},
#    'circulatingSupply': 967113527.5225,
#    'marketCap': 4648513518.249065,
#    'ts': 1631606105000,
#    'src': 'cd'},
#   'XEM': {'iso': 'XEM',
#    'name': 'NEM',
#    'slug': 'nem',
#    'change': {'percent': 2.983800306736279, 'value': 0.0051893715},
#    'ohlc': {'o': 0.1739181891,
#     'h': 0.1835339373,
#     'l': 0.1679296783,
#     'c': 0.1792809186},
#    'circulatingSupply': 8999999999,
#    'marketCap': 1613528267.291672,
#    'ts': 1631606105000,
#    'src': 'cd'},
#   'IOTA': {'iso': 'IOTA',
#    'name': 'IOTA',
#    'slug': 'iota',
#    'change': {'percent': 7.000049378775026, 'value': 0.0966868747},
#    'ohlc': {'o': 1.3812313231,
#     'h': 1.5418152964,
#     'l': 1.3080728608,
#     'c': 1.4786718226},
#    'circulatingSupply': 2779530283.277761,
#    'marketCap': 4110013109.9184327,
#    'ts': 1631606105000,
#    'src': 'cd'},
#   'DASH': {'iso': 'DASH',
#    'name': 'Dash',
#    'slug': 'dash',
#    'change': {'percent': 4.8742520419379405, 'value': 9.2485652203},
#    'ohlc': {'o': 189.7432701617,
#     'h': 214.8091872842,
#     'l': 186.6974054003,
#     'c': 199.0372578349},
#    'circulatingSupply': 10329187.1335124,
#    'marketCap': 2055893082.7178578,
#    'ts': 1631606105000,
#    'src': 'cd'},
#   'XMR': {'iso': 'XMR',
#    'name': 'Monero',
#    'slug': 'monero',
#    'change': {'percent': 3.5414931261560136, 'value': 8.8290897978},
#    'ohlc': {'o': 249.304163054,
#     'h': 275.4008536697,
#     'l': 241.6613692919,
#     'c': 257.0313516593},
#    'circulatingSupply': 17992352.72429711,
#    'marketCap': 4624598740.256223,
#    'ts': 1631606105000,
#    'src': 'cd'},
#   'TRX': {'iso': 'TRX',
#    'name': 'Tron',
#    'slug': 'tron',
#    'change': {'percent': 8.343608604661314, 'value': 0.0087033596},
#    'ohlc': {'o': 0.1043116961,
#     'h': 0.114698066,
#     'l': 0.0985969176,
#     'c': 0.1130000948},
#    'circulatingSupply': 71660220128,
#    'marketCap': 8097611670.16025,
#    'ts': 1631606105000,
#    'src': 'cd'},
#   'ICX': {'iso': 'ICX',
#    'name': 'ICON',
#    'slug': 'icon',
#    'change': {'percent': 16.97868674261289, 'value': 0.2728987167},
#    'ohlc': {'o': 1.6073016769,
#     'h': 1.9911395113,
#     'l': 1.5230749207,
#     'c': 1.8766305358},
#    'circulatingSupply': 904410462.4897869,
#    'marketCap': 1697244290.8410165,
#    'ts': 1631606105000,
#    'src': 'cd'},
#   'ETC': {'iso': 'ETC',
#    'name': 'Ethereum Classic',
#    'slug': 'ethereum-classic',
#    'change': {'percent': 2.2789459747881358, 'value': 1.2448078271},
#    'ohlc': {'o': 54.6220858621,
#     'h': 58.0374379374,
#     'l': 53.5047299388,
#     'c': 55.8854388906},
#    'circulatingSupply': 129837564.20573,
#    'marketCap': 7256029260.121105,
#    'ts': 1631606105000,
#    'src': 'cd'},
#   'QTUM': {'iso': 'QTUM',
#    'name': 'Qtum',
#    'slug': 'qtum',
#    'change': {'percent': 1.857491399392596, 'value': 0.2289085948},
#    'ohlc': {'o': 12.3235345752,
#     'h': 12.9584154867,
#     'l': 11.7664853862,
#     'c': 12.5452356251},
#    'circulatingSupply': 103729961,
#    'marketCap': 1301316802.1308932,
#    'ts': 1631606105000,
#    'src': 'cd'},
#   'BTG': {'iso': 'BTG',
#    'name': 'Bitcoin Gold',
#    'slug': 'bitcoin-gold',
#    'change': {'percent': 2.5709736120035918, 'value': 1.6037042431},
#    'ohlc': {'o': 62.3773124569,
#     'h': 69.9967624006,
#     'l': 61.223395853,
#     'c': 64.0902186376},
#    'circulatingSupply': 18834394.90456671,
#    'marketCap': 1207100487.3401332,
#    'ts': 1631606105000,
#    'src': 'cd'},
#   'LSK': {'iso': 'LSK',
#    'name': 'Lisk',
#    'slug': 'lisk',
#    'change': {'percent': 3.132370168031394, 'value': 0.104002302},
#    'ohlc': {'o': 3.3202430233,
#     'h': 3.5897306674,
#     'l': 3.2181562028,
#     'c': 3.4246074541},
#    'circulatingSupply': 144887160.39754263,
#    'marketCap': 496181649.49633735,
#    'ts': 1631606105000,
#    'src': 'cd'},
#   'USDT': {'iso': 'USDT',
#    'name': 'Tether',
#    'slug': 'tether',
#    'change': {'percent': -0.0018633172751295792, 'value': -1.86365e-05},
#    'ohlc': {'o': 1.0001810048,
#     'h': 1.0008952368,
#     'l': 0.9997957066,
#     'c': 1.0001259662},
#    'circulatingSupply': 71209203482.20892,
#    'marketCap': 71218173434.72548,
#    'ts': 1631606105000,
#    'src': 'cd'},
#   'OMG': {'iso': 'OMG',
#    'name': 'OmiseGO',
#    'slug': 'omisego',
#    'change': {'percent': -1.843802981290995, 'value': -0.1571132339},
#    'ohlc': {'o': 8.5211508779,
#     'h': 8.9434461036,
#     'l': 8.0113906634,
#     'c': 8.3691258414},
#    'circulatingSupply': 140245398.24513277,
#    'marketCap': 1173731386.5841663,
#    'ts': 1631606105000,
#    'src': 'cd'},
#   'ZEC': {'iso': 'ZEC',
#    'name': 'Zcash',
#    'slug': 'zcash',
#    'change': {'percent': 3.3962109669678595, 'value': 4.178031134},
#    'ohlc': {'o': 123.0203651851,
#     'h': 130.7902808148,
#     'l': 120.9462935669,
#     'c': 127.1936642269},
#    'circulatingSupply': 11571732.45667684,
#    'marketCap': 1471851052.617627,
#    'ts': 1631606105000,
#    'src': 'cd'},
#   'SC': {'iso': 'SC',
#    'name': 'Siacoin',
#    'slug': 'siacoin',
#    'change': {'percent': 3.2965230351526076, 'value': 0.0005894707},
#    'ohlc': {'o': 0.0178815903,
#     'h': 0.0187414447,
#     'l': 0.0170906593,
#     'c': 0.0183474875},
#    'circulatingSupply': 48846082992,
#    'marketCap': 896202896.9987184,
#    'ts': 1631606105000,
#    'src': 'cd'},
#   'ZRX': {'iso': 'ZRX',
#    'name': '0x',
#    'slug': '0x',
#    'change': {'percent': 1.2286914160559494, 'value': 0.012083354},
#    'ohlc': {'o': 0.9834327686,
#     'h': 1.0307261633,
#     'l': 0.9445868031,
#     'c': 0.9951336547},
#    'circulatingSupply': 1000000000,
#    'marketCap': 995133654.6790624,
#    'ts': 1631606105000,
#    'src': 'cd'},
#   'REP': {'iso': 'REP',
#    'name': 'Augur',
#    'slug': 'augur',
#    'change': {'percent': 1.341712044832407, 'value': 0.3331174926},
#    'ohlc': {'o': 24.8277932594,
#     'h': 25.7736335556,
#     'l': 23.8584677107,
#     'c': 25.1382871327},
#    'circulatingSupply': 11000000,
#    'marketCap': 276521158.4596208,
#    'ts': 1631606105000,
#    'src': 'cd'},
#   'WAVES': {'iso': 'WAVES',
#    'name': 'Waves',
#    'slug': 'waves',
#    'change': {'percent': -3.629449318654257, 'value': -1.1203269676},
#    'ohlc': {'o': 30.8676845783,
#     'h': 31.8475640185,
#     'l': 27.9739537854,
#     'c': 29.7321592337},
#    'circulatingSupply': 100000000,
#    'marketCap': 2973215923.3663025,
#    'ts': 1631606105000,
#    'src': 'cd'},
#   'MKR': {'iso': 'MKR',
#    'name': 'Maker',
#    'slug': 'maker',
#    'change': {'percent': 4.724838019515389, 'value': 127.9284675427},
#    'ohlc': {'o': 2707.5736144663,
#     'h': 2877.9906842878,
#     'l': 2629.3525118394,
#     'c': 2835.1325953486},
#    'circulatingSupply': 991328.3819549287,
#    'marketCap': 2810547408.3746314,
#    'ts': 1631606105000,
#    'src': 'cd'},
#   'DCR': {'iso': 'DCR',
#    'name': 'Decred',
#    'slug': 'decred',
#    'change': {'percent': 1.4709827708561454, 'value': 2.0097614726},
#    'ohlc': {'o': 136.62712524,
#     'h': 142.3394859145,
#     'l': 131.8260782037,
#     'c': 138.7043208036},
#    'circulatingSupply': 13350873.45465169,
#    'marketCap': 1851823834.6625254,
#    'ts': 1631606105000,
#    'src': 'cd'},
#   'BAT': {'iso': 'BAT',
#    'name': 'Basic Attention Token',
#    'slug': 'basic-attention-token',
#    'change': {'percent': 2.0785946654446965, 'value': 0.0154761021},
#    'ohlc': {'o': 0.744546418,
#     'h': 0.7732107974,
#     'l': 0.7158135696,
#     'c': 0.7606636081},
#    'circulatingSupply': 1500000000,
#    'marketCap': 1140995412.1305976,
#    'ts': 1631606105000,
#    'src': 'cd'},
#   'LRC': {'iso': 'LRC',
#    'name': 'Loopring',
#    'slug': 'loopring',
#    'change': {'percent': 2.0108906312488597, 'value': 0.008704924},
#    'ohlc': {'o': 0.4328889842,
#     'h': 0.4576356858,
#     'l': 0.4127329188,
#     'c': 0.4419557978},
#    'circulatingSupply': 1373873440.4424574,
#    'marketCap': 607191332.3949479,
#    'ts': 1631606105000,
#    'src': 'cd'},
#   'KNC': {'iso': 'KNC',
#    'name': 'Kyber Network',
#    'slug': 'kyber-network',
#    'change': {'percent': 1.8396951409661766, 'value': 0.0319157914},
#    'ohlc': {'o': 1.7348413139,
#     'h': 1.7982296243,
#     'l': 1.6386232535,
#     'c': 1.7666925112},
#    'circulatingSupply': 78447634.75781938,
#    'marketCap': 138592848.84757537,
#    'ts': 1631606105000,
#    'src': 'cd'},
#   'BNT': {'iso': 'BNT',
#    'name': 'Bancor',
#    'slug': 'bancor',
#    'change': {'percent': 2.7129321890906213, 'value': 0.1037984827},
#    'ohlc': {'o': 3.8260625593,
#     'h': 4.0165083757,
#     'l': 3.7148934445,
#     'c': 3.9306281832},
#    'circulatingSupply': 232460088.8773221,
#    'marketCap': 913714176.8014247,
#    'ts': 1631606105000,
#    'src': 'cd'},
#   'LINK': {'iso': 'LINK',
#    'name': 'Chainlink',
#    'slug': 'chainlink',
#    'change': {'percent': 1.1380006758981385, 'value': 0.3034413559},
#    'ohlc': {'o': 26.6644266894,
#     'h': 27.9019745498,
#     'l': 25.2491193173,
#     'c': 26.982374713},
#    'circulatingSupply': 1000000000,
#    'marketCap': 26982374712.98059,
#    'ts': 1631606105000,
#    'src': 'cd'},
#   'CVC': {'iso': 'CVC',
#    'name': 'Civic',
#    'slug': 'civic',
#    'change': {'percent': 0.5398213620994391, 'value': 0.0026693917},
#    'ohlc': {'o': 0.4944953809,
#     'h': 0.5210470599,
#     'l': 0.45949897,
#     'c': 0.497652804},
#    'circulatingSupply': 1000000000,
#    'marketCap': 497652804.008246,
#    'ts': 1631606105000,
#    'src': 'cd'},
#   'STORJ': {'iso': 'STORJ',
#    'name': 'Storj',
#    'slug': 'storj',
#    'change': {'percent': 1.2979030452227729, 'value': 0.0172808482},
#    'ohlc': {'o': 1.3314436913,
#     'h': 1.3857511897,
#     'l': 1.2740592761,
#     'c': 1.3485407569},
#    'circulatingSupply': 424999998.00001335,
#    'marketCap': 573129818.9923879,
#    'ts': 1631606105000,
#    'src': 'cd'},
#   'ANT': {'iso': 'ANT',
#    'name': 'Aragon',
#    'slug': 'aragon',
#    'change': {'percent': 1.9967204768111952, 'value': 0.110525622},
#    'ohlc': {'o': 5.5353577694,
#     'h': 5.7123265662,
#     'l': 5.344276903,
#     'c': 5.653080265},
#    'circulatingSupply': 39609523.809523806,
#    'marketCap': 223915817.35453182,
#    'ts': 1631606105000,
#    'src': 'cd'},
#   'SNGLS': {'iso': 'SNGLS',
#    'name': 'SingularDTV',
#    'slug': 'singulardtv',
#    'change': {'percent': -3.4951456310679623, 'value': -5.4e-05},
#    'ohlc': {'o': 0.001545, 'h': 0.0015534, 'l': 0.00148, 'c': 0.001491},
#    'circulatingSupply': 1000000000,
#    'marketCap': 1491000,
#    'ts': 1631598148000,
#    'src': 'cd'},
#   'MANA': {'iso': 'MANA',
#    'name': 'Decentraland',
#    'slug': 'decentraland',
#    'change': {'percent': 4.030105250123917, 'value': 0.0318266847},
#    'ohlc': {'o': 0.789723413,
#     'h': 0.8520398881,
#     'l': 0.7613320185,
#     'c': 0.8221594185},
#    'circulatingSupply': 2194080627.320146,
#    'marketCap': 1803884052.6029625,
#    'ts': 1631606105000,
#    'src': 'cd'},
#   'MLN': {'iso': 'MLN',
#    'name': 'Enzyme',
#    'slug': 'melon',
#    'change': {'percent': 1.357818367563649, 'value': 1.4091646024},
#    'ohlc': {'o': 103.7815245424,
#     'h': 109.3401051198,
#     'l': 100.072438017,
#     'c': 105.2047596287},
#    'circulatingSupply': 1824437.3190986535,
#    'marketCap': 191939489.61331573,
#    'ts': 1631606105000,
#    'src': 'cd'},
#   'DNT': {'iso': 'DNT',
#    'name': 'district0x',
#    'slug': 'district0x',
#    'change': {'percent': 2.499243280334163, 'value': 0.0042450636},
#    'ohlc': {'o': 0.1698539552,
#     'h': 0.1796596714,
#     'l': 0.1645730522,
#     'c': 0.1740647652},
#    'circulatingSupply': 1000000000,
#    'marketCap': 174064765.15884614,
#    'ts': 1631606105000,
#    'src': 'cd'},
#   'NMR': {'iso': 'NMR',
#    'name': 'Numeraire',
#    'slug': 'numeraire',
#    'change': {'percent': 0.31367951307307523, 'value': 0.1373388978},
#    'ohlc': {'o': 43.7831901902,
#     'h': 44.7591143917,
#     'l': 42.2028154605,
#     'c': 43.9334647371},
#    'circulatingSupply': 10971549.010867639,
#    'marketCap': 482018161.580699,
#    'ts': 1631606105000,
#    'src': 'cd'},
#   'DOT': {'iso': 'DOT',
#    'name': 'Polkadot',
#    'slug': 'polkadot',
#    'change': {'percent': 7.671732737031059, 'value': 2.5818787915},
#    'ohlc': {'o': 33.654441311,
#     'h': 37.0577396354,
#     'l': 31.6055060131,
#     'c': 36.2654166723},
#    'circulatingSupply': 1092257612.7987192,
#    'marketCap': 39611177441.60274,
#    'ts': 1631606105000,
#    'src': 'cd'},
#   'DAI': {'iso': 'DAI',
#    'name': 'Dai',
#    'slug': 'dai',
#    'change': {'percent': -0.01925050280531802, 'value': -0.0001926244},
#    'ohlc': {'o': 1.0006203199,
#     'h': 1.0008225613,
#     'l': 0.9996511116,
#     'c': 1.0004218702},
#    'circulatingSupply': 6273710522.5262985,
#    'marketCap': 6276357214.023899,
#    'ts': 1631606105000,
#    'src': 'cd'},
#   'UNI': {'iso': 'UNI',
#    'name': 'Uniswap',
#    'slug': 'uniswap',
#    'change': {'percent': 4.098964467563149, 'value': 0.9000146847},
#    'ohlc': {'o': 21.957123361,
#     'h': 23.3649059902,
#     'l': 21.4088176267,
#     'c': 22.8710896915},
#    'circulatingSupply': 1000000000,
#    'marketCap': 22871089691.51652,
#    'ts': 1631606105000,
#    'src': 'cd'},
#   'ATOM': {'iso': 'ATOM',
#    'name': 'Cosmos',
#    'slug': 'cosmos',
#    'change': {'percent': 16.21942311027291, 'value': 5.0195429684},
#    'ohlc': {'o': 30.9477281298,
#     'h': 38.9450778173,
#     'l': 30.3060960227,
#     'c': 36.0417055264},
#    'circulatingSupply': 268335553.969844,
#    'marketCap': 9671271018.442291,
#    'ts': 1631606105000,
#    'src': 'cd'},
#   'GRT': {'iso': 'GRT',
#    'name': 'The Graph',
#    'slug': 'the-graph',
#    'change': {'percent': 3.0859954264220066, 'value': 0.0260312566},
#    'ohlc': {'o': 0.843528685,
#     'h': 0.8796760087,
#     'l': 0.7948433983,
#     'c': 0.8692215905},
#    'circulatingSupply': 10185863258.253788,
#    'marketCap': 8853772262.012106,
#    'ts': 1631606105000,
#    'src': 'cd'},
#   'XTZ': {'iso': 'XTZ',
#    'name': 'Tezos',
#    'slug': 'tezos',
#    'change': {'percent': 13.385840158985577, 'value': 0.9199047331},
#    'ohlc': {'o': 6.872222604,
#     'h': 8.019083367,
#     'l': 6.314230554,
#     'c': 7.7811064853},
#    'circulatingSupply': 859170217.01747,
#    'marketCap': 6685294947.580781,
#    'ts': 1631606105000,
#    'src': 'cd'},
#   'FIL': {'iso': 'FIL',
#    'name': 'Filecoin',
#    'slug': 'filecoin',
#    'change': {'percent': 0.43459047056016264, 'value': 0.3412669137},
#    'ohlc': {'o': 78.5260922291,
#     'h': 83.3581931327,
#     'l': 73.0420389746,
#     'c': 78.9187470869},
#    'circulatingSupply': 106239661,
#    'marketCap': 8384300937.059099,
#    'ts': 1631606105000,
#    'src': 'cd'},
#   'NANO': {'iso': 'NANO',
#    'name': 'Nano',
#    'slug': 'nano',
#    'change': {'percent': 1.9710354562577388, 'value': 0.1050100312},
#    'ohlc': {'o': 5.3276581548,
#     'h': 5.6009502379,
#     'l': 5.1712036984,
#     'c': 5.4391253558},
#    'circulatingSupply': 133248290,
#    'marketCap': 724754152.7522438,
#    'ts': 1631606105000,
#    'src': 'cd'},
#   'WBTC': {'iso': 'WBTC',
#    'name': 'Wrapped Bitcoin ',
#    'slug': 'wrapped-bitcoin',
#    'change': {'percent': 2.8725873300456004, 'value': 1275.7967769256},
#    'ohlc': {'o': 44412.810833686,
#     'h': 46854.9571593202,
#     'l': 43440.2886119168,
#     'c': 45708.4862225742},
#    'circulatingSupply': 203271.03443419,
#    'marketCap': 9291211276.883572,
#    'ts': 1631606105000,
#    'src': 'cd'},
#   'BSV': {'iso': 'BSV',
#    'name': 'Bitcoin SV',
#    'slug': 'bitcoin-sv',
#    'change': {'percent': 2.38721248145396, 'value': 3.4989682648},
#    'ohlc': {'o': 146.5712956834,
#     'h': 156.0249123927,
#     'l': 145.6474327846,
#     'c': 150.0881033947},
#    'circulatingSupply': 18841666.29238754,
#    'marketCap': 2827909958.6198816,
#    'ts': 1631606105000,
#    'src': 'cd'},
#   'DOGE': {'iso': 'DOGE',
#    'name': 'Dogecoin',
#    'slug': 'dogecoin',
#    'change': {'percent': 0.8431844706786105, 'value': 0.0019792327},
#    'ohlc': {'o': 0.2347330554,
#     'h': 0.2450906179,
#     'l': 0.2284036875,
#     'c': 0.2366832361},
#    'circulatingSupply': 131131995502.67664,
#    'marketCap': 31036745056.330402,
#    'ts': 1631606105000,
#    'src': 'cd'},
#   'USDC': {'iso': 'USDC',
#    'name': 'USD Coin',
#    'slug': 'usdc',
#    'change': {'percent': -0.03505007412872838, 'value': -0.0003505572},
#    'ohlc': {'o': 1.0001610728,
#     'h': 1.0011166514,
#     'l': 0.9995205828,
#     'c': 0.9999631278},
#    'circulatingSupply': 26641178347.34955,
#    'marketCap': 26640196028.076527,
#    'ts': 1631606105000,
#    'src': 'cd'},
#   'OXT': {'iso': 'OXT',
#    'name': 'Orchid',
#    'slug': 'oxt',
#    'change': {'percent': 2.54141200527464, 'value': 0.0090656273},
#    'ohlc': {'o': 0.3567161601,
#     'h': 0.3724905398,
#     'l': 0.350530147,
#     'c': 0.3655997315},
#    'circulatingSupply': 1000000000,
#    'marketCap': 365599731.5441582,
#    'ts': 1631606105000,
#    'src': 'cd'},
#   'ALGO': {'iso': 'ALGO',
#    'name': 'Algorand',
#    'slug': 'algorand',
#    'change': {'percent': 4.691683853079635, 'value': 0.0967348857},
#    'ohlc': {'o': 2.0618372577,
#     'h': 2.3209835427,
#     'l': 1.9772639566,
#     'c': 2.1538868931},
#    'circulatingSupply': 5223839194.121686,
#    'marketCap': 11251558771.675236,
#    'ts': 1631606105000,
#    'src': 'cd'},
#   'BAND': {'iso': 'BAND',
#    'name': 'Band Protocol',
#    'slug': 'band-protocol',
#    'change': {'percent': 4.819268047065189, 'value': 0.4060501284},
#    'ohlc': {'o': 8.4255560071,
#     'h': 9.1681402001,
#     'l': 8.0322440315,
#     'c': 8.8377121459},
#    'circulatingSupply': 100000000,
#    'marketCap': 883771214.5872048,
#    'ts': 1631606105000,
#    'src': 'cd'},
#   'BTT': {'iso': 'BTT',
#    'name': 'BitTorrent',
#    'slug': 'bittorrent',
#    'change': {'percent': 4.250179945061219, 'value': 0.0001643506},
#    'ohlc': {'o': 0.0038669102,
#     'h': 0.0040838098,
#     'l': 0.0037345017,
#     'c': 0.0040349479},
#    'circulatingSupply': 989988481774.0297,
#    'marketCap': 3994551985.445274,
#    'ts': 1631606105000,
#    'src': 'cd'},
#   'FET': {'iso': 'FET',
#    'name': 'Fetch.ai',
#    'slug': 'fetch',
#    'change': {'percent': 12.845441166386347, 'value': 0.1035077456},
#    'ohlc': {'o': 0.8057936217,
#     'h': 1.0054237336,
#     'l': 0.7852719792,
#     'c': 0.9084930265},
#    'circulatingSupply': 1152997575,
#    'marketCap': 1047490256.443035,
#    'ts': 1631606105000,
#    'src': 'cd'},
#   'KAVA': {'iso': 'KAVA',
#    'name': 'Kava.io',
#    'slug': 'kava',
#    'change': {'percent': 0.5792489750148648, 'value': 0.035782776},
#    'ohlc': {'o': 6.1774431275,
#     'h': 6.4331072659,
#     'l': 5.8794273294,
#     'c': 6.2212701905},
#    'circulatingSupply': 144505701,
#    'marketCap': 899009009.9946707,
#    'ts': 1631606105000,
#    'src': 'cd'},
#   'PAX': {'iso': 'PAX',
#    'name': 'Paxos Standard',
#    'slug': 'paxos-standard',
#    'change': {'percent': -0.7229241092524199, 'value': -0.007287494},
#    'ohlc': {'o': 1.0080579583,
#     'h': 1.0098772371,
#     'l': 0.9994947151,
#     'c': 1.0007499623},
#    'circulatingSupply': 1002240309.42,
#    'marketCap': 1002991951.820689,
#    'ts': 1631606105000,
#    'src': 'cd'},
#   'PAXG': {'iso': 'PAXG',
#    'name': 'PAX Gold',
#    'slug': 'pax-gold',
#    'change': {'percent': 0.2598652920430415, 'value': 4.6638054359},
#    'ohlc': {'o': 1794.7011696923,
#     'h': 1806.6732108925,
#     'l': 1791.4351593079,
#     'c': 1798.8628555884},
#    'circulatingSupply': 172493.608,
#    'marketCap': 310292344.2576267,
#    'ts': 1631606105000,
#    'src': 'cd'},
#   'REN': {'iso': 'REN',
#    'name': 'Ren',
#    'slug': 'ren',
#    'change': {'percent': 3.1706032887758733, 'value': 0.0208107527},
#    'ohlc': {'o': 0.6563657082,
#     'h': 0.6885210459,
#     'l': 0.6271160002,
#     'c': 0.6767875494},
#    'circulatingSupply': 999999632.80375,
#    'marketCap': 676787300.906999,
#    'ts': 1631606105000,
#    'src': 'cd'},
#   'AAVE': {'iso': 'AAVE',
#    'name': 'Aave',
#    'slug': 'aave',
#    'change': {'percent': 7.349565609892051, 'value': 22.8079321569},
#    'ohlc': {'o': 310.3303428736,
#     'h': 337.5225932298,
#     'l': 303.3112709824,
#     'c': 333.199166565},
#    'circulatingSupply': 16000000,
#    'marketCap': 5331186665.040405,
#    'ts': 1631606105000,
#    'src': 'cd'},
#   'YFI': {'iso': 'YFI',
#    'name': 'Yearn Finance',
#    'slug': 'yearn-finance',
#    'change': {'percent': 4.88557703804454, 'value': 1542.9786766484},
#    'ohlc': {'o': 31582.3221010131,
#     'h': 33564.0533299675,
#     'l': 31124.9931545265,
#     'c': 33150.9907188179},
#    'circulatingSupply': 36666,
#    'marketCap': 1215514225.696179,
#    'ts': 1631606105000,
#    'src': 'cd'},
#   'NU': {'iso': 'NU',
#    'name': 'NuCypher',
#    'slug': 'nucypher',
#    'change': {'percent': 5.065188764569346, 'value': 0.0152559893},
#    'ohlc': {'o': 0.3011929066,
#     'h': 0.3244578707,
#     'l': 0.2956180767,
#     'c': 0.3162198353},
#    'circulatingSupply': 3885390081.7482486,
#    'marketCap': 1228637411.6669893,
#    'ts': 1631606105000,
#    'src': 'cd'},
#   'MATIC': {'iso': 'MATIC',
#    'name': 'Polygon',
#    'slug': 'polygon',
#    'change': {'percent': 2.425632319828553, 'value': 0.0300110522},
#    'ohlc': {'o': 1.2372465486,
#     'h': 1.2968857785,
#     'l': 1.2003972719,
#     'c': 1.2680554404},
#    'circulatingSupply': 10000000000,
#    'marketCap': 12680554403.519089,
#    'ts': 1631606105000,
#    'src': 'cd'}}}

# %% [markdown]
# # Step 2 - Data Tabulation

# %%
def flatten_json(coin_dict):
    flatten_dict = {}
    def flatten(x, name=''):
        if type(x) is dict:
            for key in x:
                flatten(x[key], name + key + '_')
        else:
            flatten_dict[name[:-1]] = x
    flatten(coin_dict)
    return flatten_dict

import pandas as pd
master_df = pd.DataFrame()
for coin in data['data'].keys():
    temp_df = pd.json_normalize(flatten_json(data['data'][coin]))
    master_df = master_df.append(temp_df)
master_df = master_df[['iso', 'name', 'ohlc_o', 'ohlc_h', 'ohlc_l', 'ohlc_c', 'change_percent']].reset_index(drop=True)
master_df.columns = ['Symbol', 'Name', 'Open', 'High', 'Low', 'Close', 'Pct_Change']
master_df.iloc[:, 2:] = master_df.iloc[:, 2:].apply(lambda x: round(x, 2))
master_df['Pct_Change'] = master_df['Pct_Change'] / 100
master_df = master_df.sort_values('Pct_Change', ascending=False).reset_index(drop=True)
master_df.to_csv('master_df.csv', index=False)
master_df.head()
# Out:
#   Symbol      Name   Open   High    Low  Close  Pct_Change
# 0    ICX      ICON   1.61   1.99   1.52   1.88      0.1698
# 1   ATOM    Cosmos  30.95  38.95  30.31  36.04      0.1622
# 2    XTZ     Tezos   6.87   8.02   6.31   7.78      0.1339
# 3    FET  Fetch.ai   0.81   1.01   0.79   0.91      0.1285
# 4    TRX      Tron   0.10   0.11   0.10   0.11      0.0834

# %% [markdown]
# # Step 3 - Excel Formatting

# %%
file_name = "Cryptocurrency.xlsx"
sheet_name = "Summary"

writer = pd.ExcelWriter(file_name, engine='xlsxwriter')
master_df.to_excel(writer, sheet_name=sheet_name, startrow = 2, index = False)

from datetime import datetime
workbook  = writer.book
worksheet = writer.sheets[sheet_name]

worksheet.write(0, 0, 'Cryptocurrency Pricing Summary on '+datetime.now().strftime('%d %b %Y'), workbook.add_format({'bold': True, 'color': '#E26B0A', 'size': 14}))

worksheet.write(len(master_df)+4, 0, 'Remark:', workbook.add_format({'bold': True}))
worksheet.write(len(master_df)+5, 0, 'The last update time is ' + datetime.now().strftime('%H:%M') + '.')

header_format = workbook.add_format({'bold': True, 'text_wrap': True, 'fg_color': '#FDE9D9', 'border': 1})
for col_num, value in enumerate(master_df.columns.values):
    worksheet.write(2, col_num, value, header_format)

row_idx, col_idx = master_df.shape
for r in range(row_idx):
    for c in range(col_idx):
        if c == 6:
            worksheet.write(r + 3, c, master_df.values[r, c], workbook.add_format({'border': 1, 'num_format': '0.00%'}))
        else:
            worksheet.write(r + 3, c, master_df.values[r, c], workbook.add_format({'border': 1, 'num_format': '0.00'}))

worksheet.set_column(0, 6, 12)
worksheet.set_column(1, 1, 20)
    
writer.save()
